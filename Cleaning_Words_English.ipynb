# %%
import pandas as pd
#to display the full text on the notebook without truncation
pd.set_option('display.max_colwidth', 150)

# %%
docs_df = pd.DataFrame([ ['d0', 'The sun sets in the west, painting the sky with hues of orange and pink filled.'],
                        ['d1', 'Birds chirped merrily in the lush green forest, creating a symphony of nature.'],
                        ['d2', 'The aroma of freshly brewed coffee filled the cozy cafe, welcoming patrons with its warmth.'],
                        ['d3', 'Waves crashed against the rocky shore, sending sprays of salty water into the air.'],
                        ['d4', 'Laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled.'],
                        ['d5', 'The quick brown foxes are jumping over the lazy dogs.'],
                        ['d6', 'Cats running was better than the runners running']],
                        columns=["docno", "raw_text"])

# %%
# Cleaning functions for English

import re
from snowballstemmer import stemmer
from sklearn.feature_extraction import _stop_words as stp

# %%
stp.ENGLISH_STOP_WORDS
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
################################## Removing Stop Words function ########################################################

def remove_stopWords(sentence):
    terms=[]
    stopWords= set(stp.ENGLISH_STOP_WORDS)
    for term in sentence.split() :
        if term not in stopWords :
           terms.append(term)
    return " ".join(terms)


################################## Normalizing function ########################################################


def normalize(text):
  # folding text (lower case)
  lower_string = text.lower()
  # Remove punctuation and numbers
  cleaned_string = re.sub(r'[^a-zA-Z\s]', '', lower_string)
  normalized_string = ' '.join(cleaned_string.split())
  return(normalized_string)


################################### Stemming Function ###########################################################

stemmerObj = stemmer("english")  # Use "english" or another supported language

def stem(sentence):
    return " ".join([stemmerObj.stemWord(i) for i in sentence.split()])


################################### Lemmatization Function ###########################################################

import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

def lemmatize_text(text):
    # Process the text using spaCy
    doc = nlp(text)

    # Lemmatize the text and remove stopwords and non-alphabetic characters
    #cleaned_text = ' '.join([token.lemma_.lower() for token in doc if not token.is_stop and token.is_alpha])

     # Lemmatize the text
    cleaned_text = ' '.join([token.lemma_.lower() for token in doc])

    return cleaned_text


################################################## test the functions ######################################

docs_df["nostop_text"]=docs_df["raw_text"].apply(remove_stopWords)
docs_df["NOR_text"]=docs_df["raw_text"].apply(normalize)
docs_df['text_STEM']=docs_df['raw_text'].apply(stem)
docs_df['text_lemm']=docs_df['raw_text'].apply(lemmatize_text)


display(docs_df)
# Out:
#   docno  \
# 0    d0
# 1    d1
# 2    d2
# 3    d3
# 4    d4
# 5    d5
# 6    d6
#
#                                                                                                               raw_text  \
# 0                                      The sun sets in the west, painting the sky with hues of orange and pink filled.
# 1                                       Birds chirped merrily in the lush green forest, creating a symphony of nature.
# 2                          The aroma of freshly brewed coffee filled the cozy cafe, welcoming patrons with its warmth.
# 3                                   Waves crashed against the rocky shore, sending sprays of salty water into the air.
# 4  Laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled.
# 5                                                                The quick brown foxes are jumping over the lazy dogs.
# 6                                                                     Cats running was better than the runners running
#
#                                                                               nostop_text  \
# 0                                The sun sets west, painting sky hues orange pink filled.
# 1                      Birds chirped merrily lush green forest, creating symphony nature.
# 2             The aroma freshly brewed coffee filled cozy cafe, welcoming patrons warmth.
# 3                              Waves crashed rocky shore, sending sprays salty water air.
# 4  Laughter echoed halls friends gathered crackling bonfire starry night painting filled.
# 5                                                The quick brown foxes jumping lazy dogs.
# 6                                                     Cats running better runners running
#
#                                                                                                              NOR_text  \
# 0                                       the sun sets in the west painting the sky with hues of orange and pink filled
# 1                                        birds chirped merrily in the lush green forest creating a symphony of nature
# 2                           the aroma of freshly brewed coffee filled the cozy cafe welcoming patrons with its warmth
# 3                                    waves crashed against the rocky shore sending sprays of salty water into the air
# 4  laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled
# 5                                                                the quick brown foxes are jumping over the lazy dogs
# 6                                                                    cats running was better than the runners running
#
#                                                                                                 text_STEM  \
# 0                               The sun set in the west, paint the sky with hue of orang and pink filled.
# 1                                Bird chirp merrili in the lush green forest, creat a symphoni of nature.
# 2                         The aroma of fresh brew coffe fill the cozi cafe, welcom patron with it warmth.
# 3                             Wave crash against the rocki shore, send spray of salti water into the air.
# 4  Laughter echo through the hall as friend gather around a crackl bonfir on a starri night paint filled.
# 5                                                        The quick brown fox are jump over the lazi dogs.
# 6                                                                  Cat run was better than the runner run
#
#                                                                                                       text_lemm
# 0                                    the sun set in the west , paint the sky with hue of orange and pink fill .
# 1                                   bird chirp merrily in the lush green forest , create a symphony of nature .
# 2                        the aroma of freshly brew coffee fill the cozy cafe , welcome patron with its warmth .
# 3                                 wave crash against the rocky shore , send spray of salty water into the air .
# 4  laughter echo through the hall as friend gather around a crackling bonfire on a starry night painting fill .
# 5                                                               the quick brown fox be jump over the lazy dog .
# 6                                                                           cat run be well than the runner run

# %%
### Cleaning the data using stem
docs_df["Final_text"]=docs_df["raw_text"].apply(remove_stopWords)
docs_df["Final_text"]=docs_df["Final_text"].apply(normalize)
docs_df['Final_text']=docs_df['Final_text'].apply(stem)
docs_df[['raw_text','Final_text']]
# Out:
#                                                                                                               raw_text  \
# 0                                      The sun sets in the west, painting the sky with hues of orange and pink filled.
# 1                                       Birds chirped merrily in the lush green forest, creating a symphony of nature.
# 2                          The aroma of freshly brewed coffee filled the cozy cafe, welcoming patrons with its warmth.
# 3                                   Waves crashed against the rocky shore, sending sprays of salty water into the air.
# 4  Laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled.
# 5                                                                The quick brown foxes are jumping over the lazy dogs.
# 6                                                                     Cats running was better than the runners running
#
#                                                                Final_text
# 0                          the sun set west paint sky hue orang pink fill
# 1               bird chirp merrili lush green forest creat symphoni natur
# 2          the aroma fresh brew coffe fill cozi cafe welcom patron warmth
# 3                       wave crash rocki shore send spray salti water air
# 4  laughter echo hall friend gather crackl bonfir starri night paint fill
# 5                                       the quick brown fox jump lazi dog
# 6                                               cat run better runner run

# %%
#cleaning data using lemma
docs_df["lemma_Final_text"]=docs_df["raw_text"].apply(remove_stopWords)
docs_df["lemma_Final_text"]=docs_df["lemma_Final_text"].apply(normalize)
docs_df['lemma_Final_text']=docs_df['lemma_Final_text'].apply(lemmatize_text)
docs_df[['raw_text','lemma_Final_text']]
# Out:
#                                                                                                               raw_text  \
# 0                                      The sun sets in the west, painting the sky with hues of orange and pink filled.
# 1                                       Birds chirped merrily in the lush green forest, creating a symphony of nature.
# 2                          The aroma of freshly brewed coffee filled the cozy cafe, welcoming patrons with its warmth.
# 3                                   Waves crashed against the rocky shore, sending sprays of salty water into the air.
# 4  Laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled.
# 5                                                                The quick brown foxes are jumping over the lazy dogs.
# 6                                                                     Cats running was better than the runners running
#
#                                                               lemma_Final_text
# 0                              the sun set west paint sky hue orange pink fill
# 1                  bird chirp merrily lush green forest create symphony nature
# 2           the aroma freshly brew coffee fill cozy cafe welcome patron warmth
# 3                            wave crash rocky shore send spray salty water air
# 4  laughter echo hall friend gather crackle bonfire starry night painting fill
# 5                                            the quick brown fox jump lazy dog
# 6                                                      cat run well runner run

# %% [markdown]
# **Stemming** reduces words to their root or base form, often resulting in non-linguistic roots. **Lemmatization**, on the other hand, reduces words to their dictionary form (lemma), preserving the linguistic meaning. Stemming is faster but may not always produce valid words, whereas lemmatization is more accurate but can be slower.

# %%
def stem_preprocess(sentence):
  # apply preprocessing steps on the given sentence
  sentence =remove_stopWords(sentence)
  sentence =normalize(sentence)
  sentence =stem(sentence)
  return sentence


def lemma_preprocess(sentence):
  # apply preprocessing steps on the given sentence
  sentence =remove_stopWords(sentence)
  sentence =normalize(sentence)
  sentence =lemmatize_text(sentence)
  return sentence


docs_df["Fstem_text"]=docs_df["raw_text"].apply(stem_preprocess)
docs_df["Flemma_text"]=docs_df["raw_text"].apply(lemma_preprocess)


docs_df[['raw_text','Fstem_text','Flemma_text']]
# Out:
#                                                                                                               raw_text  \
# 0                                      The sun sets in the west, painting the sky with hues of orange and pink filled.
# 1                                       Birds chirped merrily in the lush green forest, creating a symphony of nature.
# 2                          The aroma of freshly brewed coffee filled the cozy cafe, welcoming patrons with its warmth.
# 3                                   Waves crashed against the rocky shore, sending sprays of salty water into the air.
# 4  Laughter echoed through the halls as friends gathered around a crackling bonfire on a starry night painting filled.
# 5                                                                The quick brown foxes are jumping over the lazy dogs.
# 6                                                                     Cats running was better than the runners running
#
#                                                                Fstem_text  \
# 0                          the sun set west paint sky hue orang pink fill
# 1               bird chirp merrili lush green forest creat symphoni natur
# 2          the aroma fresh brew coffe fill cozi cafe welcom patron warmth
# 3                       wave crash rocki shore send spray salti water air
# 4  laughter echo hall friend gather crackl bonfir starri night paint fill
# 5                                       the quick brown fox jump lazi dog
# 6                                               cat run better runner run
#
#                                                                    Flemma_text
# 0                              the sun set west paint sky hue orange pink fill
# 1                  bird chirp merrily lush green forest create symphony nature
# 2           the aroma freshly brew coffee fill cozy cafe welcome patron warmth
# 3                            wave crash rocky shore send spray salty water air
# 4  laughter echo hall friend gather crackle bonfire starry night painting fill
# 5                                            the quick brown fox jump lazy dog
# 6                                                      cat run well runner run
