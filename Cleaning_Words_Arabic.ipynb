# %%
#install the Arabic stop words library
# !pip install Arabic-Stopwords
#we need to import the following libraries.
import pandas as pd
#to display the full text on the notebook without truncation
pd.set_option('display.max_colwidth', 150)
import numpy as np
import re
from snowballstemmer import stemmer
from tqdm import tqdm
import arabicstopwords.arabicstopwords as stp
# Out:
# Requirement already satisfied: Arabic-Stopwords in /usr/local/lib/python3.10/dist-packages (0.4.3)
# Requirement already satisfied: pyarabic>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from Arabic-Stopwords) (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic>=0.6.2->Arabic-Stopwords) (1.16.0)

# %%
stopWords= set(stp.stopwords_list())
stopWords
# Out:
# {'بأسفلها',
#  'وعاد',
#  'فذاك',
#  'ألازلت',
#  'ولجنوب',
#  'وتجاهكما',
#  'أمهما',
#  'ولمنهم',
#  'ماانفك',
#  'فيهم',
#  'ألكأنكما',
#  'وبذوينا',
#  'أبذواتي',
#  'أكثر',
#  'ليلها',
#  'فلأيتهن',
#  'ولكل',
#  'ومعهم',
#  'وهنالك',
#  'وكأولئك',
#  'ولذويكم',
#  'أولذانك',
#  'وعننا',
#  'فضحوة',
#  'فبغروبكم',
#  'لشبههما',
#  'أفوقي',
#  'ألخلفكما',
#  'لحظتهم',
#  'فلأقلهما',
#  'فبزمانكم',
#  'أبسواهما',
#  'وبذاتهن',
#  'مرة',
#  'فأنا',
#  'وكحسبي',
#  'كشرقي',
#  'أولديك',
#  'وسبحانكن',
#  'أكأجمعي',
#  'فكجنبه',
#  'فكأكثرنا',
#  'فبتلقائه',
#  'أوبعيننا',
#  'وليتهم',
#  'كأولاء',
#  'ومابرحن',
#  'وكاللذين',
#  'وبأننا',
#  'أعنهم',
#  'أأجمع',
#  'وابننا',
#  'أكبعضنا',
#  'أمامهم',
#  'لسوانا',
#  'وبكلهما',
#  'أولازلن',
#  'فسواكن',
#  'وأيضا',
#  'فكنفسنا',
#  'أجميعهم',
#  'ألست',
#  'ولأصبح',
#  'بأي',
#  'فبعينكن',
#  'أوراءنا',
#  'اللائي',
#  'ولمثلهن',
#  'أوكسواه',
#  'أفشمالي',
#  'ألشبهك',
#  'وبعدهما',
#  'بحميها',
#  'وتلقاءكم',
#  'وفيهن',
#  'لهؤلاء',
#  'غروبهما',
#  'فحسبي',
#  'فللتي',
#  'أفكعينكم',
#  'ولوراءكما',
#  'أولشماله',
#  'فبليلهن',
#  'بذه',
#  'أفأمامهن',
#  'فبشبهي',
#  'فهكذا',
#  'لشهري',
#  'فلإليكما',
#  'فبشبهه',
#  'أوجميعكما',
#  'فلذاتهم',
#  'أولعامتهن',
#  'أعنكما',
#  'ولحميه',
#  'بشطرهم',
#  'فلإليك',
#  'ولذا',
#  'أوراءكم',
#  'أفلعامتك',
#  'فأمسى',
#  'فبجميعك',
#  'أفبسوى',
#  'بابني',
#  'فبكلهن',
#  'أفكنفسها',
#  'ولنفسكم',
#  'كلحظتكم',
#  'وإذا',
#  'ألأجمعهن',
#  'وعني',
#  'وكجميعنا',
#  'لكم',
#  'ماانفككت',
#  'فكالألى',
#  'فلشهرهما',
#  'فكغروبكن',
#  'بالذي',
#  'بأسفلكم',
#  'أفغيره',
#  'ولكأنما',
#  'أفأنتم',
#  'فبمثله',
#  'وكذاتكن',
#  'فكلحظتكما',
#  'ولكلكم',
#  'وكليلكن',
#  'أفكتلكما',
#  'أسواهن',
#  'أفأجمعهن',
#  'ولإليكن',
#  'فلأيك',
#  'وكساعة',
#  'أفكلتا',
#  'ذووه',
#  'فكعينكما',
#  'وكخلفكم',
#  'أفوراء',
#  'فعنهما',
#  'وبمثلهما',
#  'أوكمثلهما',
#  'أفعامتي',
#  'أوكأنما',
#  'كأجمعي',
#  'أوهذان',
#  'أولشبه',
#  'وكساعتك',
#  'وأثناءهم',
#  'فكذاتها',
#  'فلمعكم',
#  'بنحوهم',
#  'فبأخي',
#  'وحسبهن',
#  'ولليلكم',
#  'فلأبيكم',
#  'ولتحتك',
#  'ألغيرهن',
#  'أفلفيه',
#  'لعامتكما',
#  'وضمن',
#  'أفيمينكن',
#  'وبالذي',
#  'وبابنكم',
#  'أومعه',
#  'وكشبهكما',
#  'لديكن',
#  'أولديكم',
#  'أوبسواهن',
#  'لذلكم',
#  'ألخلفكم',
#  'أوليمينكما',
#  'وشرقكن',
#  'كساعتكما',
#  'أوأولئكم',
#  'وكشرق',
#  'فإذ',
#  'فبغروب',
#  'وكسوانا',
#  'ليلهما',
#  'فبليلهم',
#  'كأقلك',
#  'أفأمامها',
#  'ووراءكما',
#  'ولذاك',
#  'فابنك',
#  'أوكأولئك',
#  'أولعلهم',
#  'لظل',
#  'أشبهك',
#  'أمامكما',
#  'أوكشبهك',
#  'فلشبهكن',
#  'فلشبههم',
#  'وراء',
#  'بغربك',
#  'فلوقته',
#  'لازلن',
#  'أفلعينكن',
#  'أبأولاء',
#  'لمثل',
#  'لمنكما',
#  'وأنشأ',
#  'أفهذه',
#  'بعينهما',
#  'كتلكما',
#  'فشبهها',
#  'وأناهن',
#  'ألغيرنا',
#  'أبوه',
#  'لحسبكن',
#  'فلأضحى',
#  'بجنبي',
#  'أبسواي',
#  'لكأنكن',
#  'كساعتهم',
#  'وبأجمعها',
#  'وكأقلي',
#  'وبفي',
#  'فلا',
#  'كجنبكم',
#  'وببعضهم',
#  'ومعها',
#  'أفلخلفكما',
#  'أوكسواكم',
#  'ولنحوهن',
#  'وكأعليه',
#  'أفوقهما',
#  'وكجنوبكن',
#  'كغربهما',
#  'فأصبح',
#  'ألم',
#  'فكأجمعك',
#  'أفلعنكن',
#  'لأنانا',
#  'فإياها',
#  'أفكهذا',
#  'فلحمي',
#  'فبأيتهن',
#  'وبذواتي',
#  'أبضعهم',
#  'فلورائي',
#  'أفعليكما',
#  'هذا',
#  'أوشبههم',
#  'أفلعلى',
#  'أولديكما',
#  'فلشمالنا',
#  'أولكأن',
#  'ولأبيكم',
#  'وتلقاءهم',
#  'ولأكثره',
#  'أشمالكن',
#  'أباهن',
#  'فبالذي',
#  'فذوينا',
#  'غربها',
#  'أفكحسبنا',
#  'فحينهن',
#  'أككلهن',
#  'كشرقكم',
#  'ولجنبنا',
#  'أولنحوهما',
#  'أفبمثلنا',
#  'ولدنكم',
#  'وبليلهن',
#  'أكأجمعكما',
#  'فكلحظتهم',
#  'ولمثلهما',
#  'وكأنهن',
#  'وتينك',
#  'واخلولق',
#  'أوكسواكما',
#  'فلكلكم',
#  'فلأمامها',
#  'نفسهن',
#  'أفلكأنهم',
#  'غيرها',
#  'أوكغيركن',
#  'ألنحوكن',
#  'فاللاتي',
#  'فبغربكما',
#  'أكأجمعهم',
#  'فكفيها',
#  'ككلتا',
#  'ألمنهن',
#  'كأي',
#  'وخلاهم',
#  'ولعليهن',
#  'فمما',
#  'كجنبهم',
#  'لأقلكم',
#  'أعنكم',
#  'لفيها',
#  'فلكن',
#  'فكلتا',
#  'فبأعلى',
#  'فهن',
#  'فككلهن',
#  'بينهما',
#  'سواه',
#  'ولأعلينا',
#  'ولعيننا',
#  'لزمانك',
#  'وفاهما',
#  'لعليكم',
#  'وكليلكم',
#  'فشرع',
#  'فحموي',
#  'ففيك',
#  'أفبكليكما',
#  'فككلك',
#  'وكشهرها',
#  'فذووكم',
#  'بينه',
#  'أفبضع',
#  'كأبي',
#  'وكوقتك',
#  'وحم',
#  'معكما',
#  'فبحمينا',
#  'فكأكثري',
#  'بأقلنا',
#  'ولبعضهم',
#  'كسواهم',
#  'وراءك',
#  'عليها',
#  'أفبأولالك',
#  'فشهري',
#  'أفكتلك',
#  'أوسواك',
#  'فبماذا',
#  'ذ',
#  'ألكأنها',
#  'ولساعتي',
#  'وخلالي',
#  'أولإنها',
#  'أفلعلكن',
#  'شطره',
#  'كغير',
#  'وكنحونا',
#  'أونفسكن',
#  'فلغروبكما',
#  'أولشمال',
#  'وكفيكن',
#  'أفبنفسك',
#  'ألكلهم',
#  'وكحميك',
#  'لعينها',
#  'أوبكلهن',
#  'فأنكم',
#  'وبكما',
#  'ولأخي',
#  'وكزمانكم',
#  'فأجمع',
#  'فذواتا',
#  'بعضي',
#  'فأخوهم',
#  'أفكأنك',
#  'فكأننا',
#  'وكنفسنا',
#  'تجاهكما',
#  'ولمنكما',
#  'لأعليك',
#  'لعلهن',
#  'ولعنك',
#  'أولجميعك',
#  'وكحسبكم',
#  'فكجنوب',
#  'وأقلكما',
#  'لإنك',
#  'فلأجمعي',
#  'جنوبي',
#  'كلهما',
#  'ومثلهم',
#  'وبته',
#  'أنحو',
#  'وكغيركم',
#  'وكساعتي',
#  'فذوونا',
#  'لعمره',
#  'فأباك',
#  'فكجنبكما',
#  'وبأخيك',
#  'وكأبيكم',
#  'فيم',
#  'أوبنحوهن',
#  'وبهما',
#  'أفإليهما',
#  'فعامته',
#  'كعامتهن',
#  'أولإليه',
#  'بينهم',
#  'فكمثله',
#  'لعنهن',
#  'فلحظتكما',
#  'أوخلفهن',
#  'أوحسبما',
#  'أوكهاته',
#  'لشطرنا',
#  'فكأعلي',
#  'أفخلفنا',
#  'أخينا',
#  'فكشهره',
#  'وفاكم',
#  'فأخانا',
#  'ألديك',
#  'أيهما',
#  'وكالذين',
#  'وجعل',
#  'فحسبكم',
#  'بشبههم',
#  'جنوبك',
#  'وفيهم',
#  'بهنالك',
#  'ولديهم',
#  'وبدونكم',
#  'فأمد',
#  'أولذاك',
#  'أفلمنهما',
#  'أولعامتها',
#  'فهاتي',
#  'فكزمانهما',
#  'أفكجميعكما',
#  'أوكجميعي',
#  'فذووها',
#  'فكالذي',
#  'كمثلكم',
#  'ولحسب',
#  'فمساء',
#  'بأنهن',
#  'لحميكن',
#  'فذويهم',
#  'أفبسواكن',
#  'وغربهن',
#  'أفلشمالهم',
#  'أوحسبهما',
#  'فمعكم',
#  'وبيد',
#  'ضمني',
#  'أشبهي',
#  'كحسبنا',
#  'أسوانا',
#  'أفبنحوهما',
#  'ولشرق',
#  'كاد',
#  'فأيتنا',
#  'لأكثرهم',
#  'ولسوف',
#  'وإياهن',
#  'فلوراءك',
#  'وكأجمعكما',
#  'فلتحتنا',
#  'وحواليهن',
#  'أببعضهم',
#  'أفليسوا',
#  'وأناكم',
#  'فأيته',
#  'بذوي',
#  'فعندئذ',
#  'وآنئذ',
#  'كحميهما',
#  'لجنبنا',
#  'لكلهن',
#  'وسواكم',
#  'أوجميعنا',
#  'بذاتهما',
#  'ولأبيهما',
#  'كأسفلهن',
#  'مابرحا',
#  'لعمركم',
#  'ولذاتي',
#  'فلبعضنا',
#  'فبأقلي',
#  'حموه',
#  'أوكعينهم',
#  'وبغروبها',
#  'وكبعضه',
#  'وتلقاءنا',
#  'وكخلفهن',
#  'أفلنفسكما',
#  'بساعة',
#  'لمثلهم',
#  'أفلتحتنا',
#  'أوعينكم',
#  'ولإلى',
#  'أفعنهم',
#  'أفلعلنا',
#  'أوكبعضكن',
#  'أفبنحوها',
#  'وبعضهم',
#  'أفبهن',
#  'ووراءكن',
#  'وضمني',
#  'ولغربهن',
#  'أولوراءه',
#  'بفيكن',
#  'كحميهن',
#  'لهذه',
#  'بشرقهم',
#  'فكهم',
#  'وأخوه',
#  'أوغيرها',
#  'فكساعتها',
#  'بعامتي',
#  'أفلذينك',
#  'وغيركم',
#  'أولإني',
#  'فلشرقي',
#  'ولسواهما',
#  'فبأولالك',
#  'بسواهن',
#  'أفلمثلكما',
#  'أوأناكن',
#  'فأثناءهما',
#  'للحظتهن',
#  'فلإلينا',
#  'وكي',
#  'كعامته',
#  'لذويكن',
#  'وتحتي',
#  'ببعض',
#  'أولإليهما',
#  'لفي',
#  'كذويها',
#  'وبخلفهم',
#  'أفلغيرهما',
#  'حين',
#  'وإما',
#  'وشبهكم',
#  'فأيهم',
#  'بأننا',
#  'ولأمامكما',
#  'أفلنحوكم',
#  'هاؤم',
#  'أوشمالهم',
#  'أبمثلكن',
#  'أفلنفسه',
#  'أفعينكن',
#  'أفبضعك',
#  'فكجميعكن',
#  'شرقنا',
#  'أفلست',
#  'وسبحان',
#  'أونحوكم',
#  'بأكثرهم',
#  'وأناي',
#  'فلعلها',
#  'أوهاتي',
#  'وكشطرهم',
#  'لأولالك',
#  'فغيرهم',
#  'ألعينك',
#  'ومازلت',
#  'أفلإليها',
#  'ألأمامهما',
#  'أفجميعه',
#  'فكأيك',
#  'كنفسكما',
#  'فأثناءكما',
#  'خلفكم',
#  'ألعني',
#  'لحميها',
#  'وبجنبهما',
#  'فسبحاني',
#  'فآض',
#  'للواتي',
#  'لإلى',
#  'فباللذين',
#  'أهكذا',
#  'أفأمامكم',
#  'أومعنا',
#  'أوأمامهما',
#  'وعداني',
#  'كعينكم',
#  'بكلنا',
#  'ألجميعها',
#  'أولعيننا',
#  'وجنوبها',
#  'فلكلهم',
#  'ونحوك',
#  'أفأناكن',
#  'وكأخينا',
#  'أفكذلك',
#  'وبأجمعكن',
#  'لكلتا',
#  'فمافتئتم',
#  'أغيري',
#  'أفلهن',
#  'فكشبهكما',
#  'فلديهن',
#  'ولوراءكن',
#  'بأجمع',
#  'أفعينك',
#  'ص',
#  'أولسواكما',
#  'وأنت',
#  'بن',
#  'فعامتكما',
#  'وبلحظتكن',
#  'فلأجمعه',
#  'وبعامتها',
#  'أبحسبكن',
#  'وبوقتكن',
#  'فعنهم',
#  'أفكنحوي',
#  'أفبأجمعكم',
#  'أكسواها',
#  'أفلسواكما',
#  'أوكشبهي',
#  'حموهما',
#  'فحميه',
#  'مني',
#  'ببعضكم',
#  'ولأمامكم',
#  'وخلفكن',
#  'وإليهم',
#  'كليلهما',
#  'بأكثره',
#  'أوهاذين',
#  'فبضعها',
#  'أفكأنهم',
#  'لمثلها',
#  'فبكلنا',
#  'ولحظتهن',
#  'فبعين',
#  'وبهو',
#  'أعنه',
#  'ولذوي',
#  'فجميعك',
#  'ولمثله',
#  'أوثمة',
#  'أوبأولاء',
#  'أفبمثلهم',
#  'وكأكثركن',
#  'فأجمعكما',
#  'وكمن',
#  'أوأمامك',
#  'فلازالا',
#  'ولأناي',
#  'لغروبهما',
#  'وكأعلي',
#  'فلغربكن',
#  'فكفي',
#  'ألعليهم',
#  'ولهذه',
#  'أتلك',
#  'فبجميعكم',
#  'فبأقلكما',
#  'ولإليها',
#  'ونفسهم',
#  'فغدا',
#  'فمابرحا',
#  'ألخلفهم',
#  'بكلكن',
#  'أوبأجمعنا',
#  'ولاستحال',
#  'ولعمرها',
#  'أفكعامته',
#  'لعين',
#  'أوبجميعكما',
#  'كأعليك',
#  'لذويها',
#  'لنحوهن',
#  'كأجمع',
#  'أفلمنكما',
#  'فبجنبكما',
#  'كسواهما',
#  'لجميعهم',
#  'أكذلك',
#  'ببعضكن',
#  'وفا',
#  'كجنبهن',
#  'أولفوقكم',
#  'لكلكما',
#  'أفمعي',
#  'أثناء',
#  'وحاشانا',
#  'أفلإلينا',
#  'أعن',
#  'بأسفلهن',
#  'فكأسفل',
#  'فقلما',
#  'لإنهن',
#  'فصار',
#  'كأيك',
#  'ولشمالهن',
#  'فجميعكن',
#  'أفشمالهما',
#  'أفلازالوا',
#  'فبأعليكم',
#  'ولعامتنا',
#  'أإلى',
#  'لهذا',
#  'فكاللواتي',
#  'أعينكن',
#  'وبزمانهن',
#  'أفأناهما',
#  'ولإنها',
#  'ألمثله',
#  'أونحوهم',
#  'وأقلي',
#  'وبعيننا',
#  'فحموكن',
#  'وكأبيكن',
#  'الذين',
#  'حموكم',
#  'بشهركن',
#  'وبشهرهن',
#  'أفخلفكم',
#  'أولازلتن',
#  'ولذواتي',
#  'كابنكم',
#  'فكغروبهم',
#  'فحميهم',
#  'ولغربها',
#  'فدونك',
#  'فكتلقائهم',
#  'أوبغيركم',
#  'فأجمعك',
#  'فلشطر',
#  'ألغيركن',
#  'حسبكم',
#  'فبغربك',
#  'أفكهما',
#  'وأنتم',
#  'بأخيكم',
#  'فكابنهن',
#  'فبشطري',
#  'أولأجمعكن',
#  'فبلحظتكم',
#  'فبحسب',
#  'أومنه',
#  'أفبتلك',
#  'ونحوها',
#  'أفلوراءكم',
#  'فوقتكم',
#  'أولفيهم',
#  'فقبلما',
#  'فيمين',
#  'فبينهم',
#  'لعمركما',
#  'غير',
#  'ألإنك',
#  'أوشبهكم',
#  'كحسبهن',
#  'كشهر',
#  'فلكلكما',
#  'أفمثلكن',
#  'أوبذلكن',
#  'وشبهها',
#  'أوعامتنا',
#  'وللحظتك',
#  'وآه',
#  'وكوقت',
#  'فبعيننا',
#  'أوذاك',
#  'أوبعامتك',
#  'ولليلهما',
#  'وجنبكما',
#  'أكأجمعهن',
#  'لأيته',
#  'بغيركما',
#  'وبأعلينا',
#  'أفلعلكم',
#  'كتلقائهما',
#  'لوقتهم',
#  'أفأمامنا',
#  'بأنكن',
#  'فماانفككتم',
#  'أوكحسبهما',
#  'فلكرب',
#  'وتلقاءهما',
#  'أثناءكم',
#  'أكأولئك',
#  'ألغير',
#  'فبأنكم',
#  'فمافتئتن',
#  'ولنحوك',
#  'وشهرهن',
#  'ولأيتك',
#  'ألعامتكن',
#  'أإليها',
#  'أفعامتكم',
#  'فلشهرنا',
#  'أفنفسكما',
#  'وبتلقائهما',
#  'فكأيتهم',
#  'كذاتي',
#  'وكفيكم',
#  'ذواتي',
#  'كهذا',
#  'فكلحظتكن',
#  'فلأكثرها',
#  'وكأبيهما',
#  'فكأعليكن',
#  'فلغيرهم',
#  'ولخلفكن',
#  'كذاتهم',
#  'أنحونا',
#  'فلذاتك',
#  'أفلحسبها',
#  'وغدا',
#  'فبغروبهم',
#  'ولجنوبهم',
#  'أوكعامتكن',
#  'أوإلينا',
#  'ضمنها',
#  'ولكأنكما',
#  'أفبحسبها',
#  'كاللذين',
#  'أوبعينك',
#  'فجنوبهما',
#  'أفلإنهن',
#  'أفذلكن',
#  'أفبجميعهن',
#  'وحولها',
#  'أولعلنا',
#  'ولأكثر',
#  'لسواهم',
#  'وأمامنا',
#  'فسبحانها',
#  'مابرحتم',
#  'أولعليكم',
#  'أولغيركما',
#  'أفلي',
#  'أفكأجمع',
#  'لشبههن',
#  'وكابنهن',
#  'أوبك',
#  'أعينهم',
#  'بذلكن',
#  'عنهن',
#  'أوشمالهما',
#  'ولعينهن',
#  'فلمنها',
#  'فككلهما',
#  'أوإننا',
#  'وسواهما',
#  'وأسفلكما',
#  'أولكلهم',
#  'كعامتكم',
#  'وبمثلي',
#  'ولنحوكما',
#  'أوحسبكن',
#  'لجنوبك',
#  'أوليستا',
#  'لعمر',
#  'أيا',
#  'لأمامها',
#  'لكنك',
#  'وبنحونا',
#  'فأعلي',
#  'بهناك',
#  'أكشبهنا',
#  'فعندهن',
#  'ليتكم',
#  'بأولئك',
#  'فأباها',
#  'تحتكم',
#  'أوإلى',
#  'فحميكن',
#  'أفلعينكم',
#  'حيث',
#  'لحسبك',
#  'فلن',
#  'لازالتا',
#  'بغيرهم',
#  'لأينا',
#  'فلمنهم',
#  'وكالألى',
#  'أفمعكما',
#  'حسبهم',
#  'أنكن',
#  'ففيه',
#  'أنتن',
#  'لشرع',
#  'أوفلان',
#  'فلذواتي',
#  'ولأجمعه',
#  'كتلقائهن',
#  'كشطرنا',
#  'أولعليه',
#  'لكيلا',
#  'فأخي',
#  'كلها',
#  'لعامتي',
#  'لعينكم',
#  'فلزماننا',
#  'فغيركم',
#  'فأخيهن',
#  'أفيمينكما',
#  'فبغروبه',
#  'بذاتهم',
#  'وكذينك',
#  'جميعنا',
#  'ولما',
#  'فحماه',
#  'ش',
#  'أومنكم',
#  'فبزمانكن',
#  'حينكما',
#  'أويمينها',
#  'أفبضعنا',
#  'وكحسبه',
#  'وللألاء',
#  'أكثري',
#  'أفبه',
#  'ولذاتكما',
#  'فوقت',
#  'بليلكما',
#  'كذلك',
#  'أأناهن',
#  'وإيه',
#  'أفلحسبهن',
#  'أوحسبك',
#  'أفبأجمعهما',
#  'وتجاهنا',
#  'لمثله',
#  'فلعنه',
#  'أفكسواكما',
#  'وإنكن',
#  'لمننا',
#  'بأجمعهما',
#  'بذاتكم',
#  'فماانفكتا',
#  'وكابنكن',
#  'كهذه',
#  'وبغروبك',
#  'ألكأنكم',
#  'ولشرقها',
#  'فطفق',
#  'ولتحت',
#  'بنفسكما',
#  'أوبسواكما',
#  'وأف',
#  'بعامتكم',
#  'أفكنفسك',
#  'فمثلكما',
#  'ألعنه',
#  'وأمامه',
#  'وقط',
#  'وعلق',
#  'لكلنا',
#  'هؤلاء',
#  'لحميكم',
#  'أفكلاهما',
#  'فلذينك',
#  'ولغروبكما',
#  'أفبنحوي',
#  'فماانفككت',
#  'فاي',
#  'وبأقلكما',
#  'وبشهر',
#  'إنه',
#  'فلأسفلك',
#  'فلعمرها',
#  'أكسواكن',
#  'فالآن',
#  'بها',
#  'لتحتهم',
#  'ولذات',
#  'أثناءك',
#  'حاشاهن',
#  'وغروبهن',
#  'ولبعضنا',
#  'لجنبكم',
#  'فلمثلكن',
#  'وكهو',
#  'وبعين',
#  'أفلشبه',
#  'فلجنبكن',
#  'د',
#  'أوسوى',
#  'أوبسواهم',
#  'الذي',
#  'بيني',
#  'فبي',
#  'وكعينهما',
#  'مكانكن',
#  'فلساعة',
#  'فوقته',
#  'أوكنحوها',
#  'لغربه',
#  'أكجميعك',
#  'وحسبكما',
#  'أولفيهما',
#  'حسبكن',
#  'ولشهر',
#  'بشرق',
#  'أفلإني',
#  'حتى',
#  'فغيري',
#  'وتلكم',
#  'ولبعضك',
#  'فلسواكم',
#  'ألما',
#  'وبابن',
#  'فمازالا',
#  'بحسبها',
#  'ولنحن',
#  ...}

# %%
print('the number of stop words in this library" : ', len(stopWords))

# add more words as needed based on the dataset used

stopWords.add("هاشتاق")
print('the number of stop words in this library" : ', len(stopWords))
# Out:
# the number of stop words in this library" :  13465
# the number of stop words in this library" :  13466

# %%
######################### removing Stop Words function ####################################

def remove_stop_words(sentence):
    terms=[]
    stopWords= set(stp.stopwords_list())
    for term in sentence.split() :
        if term not in stopWords :
           terms.append(term)
    return " ".join(terms)

############################# normalize function ###########################################

def normalize(text):
    text = re.sub("[إأٱآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    return(text)

############################# stemming function ############################################

ar_stemmer = stemmer("arabic")
def stem(sentence):
    return " ".join([ar_stemmer.stemWord(i) for i in sentence.split()])


############################# perform all preprocessing steps ###############################


def preprocess(sentence):
  sentence =remove_stop_words(sentence)
  sentence =normalize(sentence)
  sentence =stem(sentence)
  return sentence

# %%
data=pd.DataFrame()
data=pd.read_csv("https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-01.txt", sep='\t')
data
# Out:
#                  tweetID  \
# 0     549679192804061184
# 1     549699343666532352
# 2     549711593487888387
# 3     549719610459967488
# 4     549720880717508608
# ...                  ...
# 4995  551574113324920832
# 4996  551574871797272576
# 4997  551574876092256256
# 4998  551575878141222912
# 4999  551576182794506240
#
#                                                                                                                                        tweetText
# 0     الاعدام لعامل مطعم قتل زميله طعناً في "البيادر" أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي... http://t.co/H0txdjv3Kn
# 1       #الأخبار ▪ تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع: أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ... http://t.co/GM4jmpAWbR
# 2                                             @helale9999 عشآن أعطيتك وحده صميم صرت ترمي أعذار ...حقق العالميةة و أرجع كلمني يَ الأياب الانتحاري
# 3                             #النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص - شبكة الصين http://t.co/r5zFEuzAPu
# 4                                             البحرين: ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا http://t.co/t4A5bNrqyh
# ...                                                                                                                                          ...
# 4995       «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا - الرياض - الرياض «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا... http://t.co/44YL32E037
# 4996                                  قصيدة مهداة إلى الشيخ/ ضيف الله بن سمار كلمات/ سلطان حامد بن سمار اداء/ عمر الشلآحي http://t.co/pQ8p6r4n0D
# 4997                                                                                                                         العفو عند المقبرة!!
# 4998                                              #للمرة الأولى منذ 92 عاما.. تركيا تسمح ببناء كنيسة جديدة - مجلة الرسائل http://t.co/0bUDDDtD8u
# 4999                   جماعة "بوكو حرام" الإرهابية تختطف الشباب في ولاية "بورنو" شمال شرقي نيجيريا http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
# [5000 rows x 2 columns]

# %%
data['Clean_Text']=data['tweetText'].apply(preprocess)
data
# Out:
#                  tweetID  \
# 0     549679192804061184
# 1     549699343666532352
# 2     549711593487888387
# 3     549719610459967488
# 4     549720880717508608
# ...                  ...
# 4995  551574113324920832
# 4996  551574871797272576
# 4997  551574876092256256
# 4998  551575878141222912
# 4999  551576182794506240
#
#                                                                                                                                        tweetText  \
# 0     الاعدام لعامل مطعم قتل زميله طعناً في "البيادر" أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي... http://t.co/H0txdjv3Kn
# 1       #الأخبار ▪ تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع: أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ... http://t.co/GM4jmpAWbR
# 2                                             @helale9999 عشآن أعطيتك وحده صميم صرت ترمي أعذار ...حقق العالميةة و أرجع كلمني يَ الأياب الانتحاري
# 3                             #النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص - شبكة الصين http://t.co/r5zFEuzAPu
# 4                                             البحرين: ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا http://t.co/t4A5bNrqyh
# ...                                                                                                                                          ...
# 4995       «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا - الرياض - الرياض «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا... http://t.co/44YL32E037
# 4996                                  قصيدة مهداة إلى الشيخ/ ضيف الله بن سمار كلمات/ سلطان حامد بن سمار اداء/ عمر الشلآحي http://t.co/pQ8p6r4n0D
# 4997                                                                                                                         العفو عند المقبرة!!
# 4998                                              #للمرة الأولى منذ 92 عاما.. تركيا تسمح ببناء كنيسة جديدة - مجلة الرسائل http://t.co/0bUDDDtD8u
# 4999                   جماعة "بوكو حرام" الإرهابية تختطف الشباب في ولاية "بورنو" شمال شرقي نيجيريا http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
#                                                                                                            Clean_Text
# 0     اعدام لعامل مطعم قتل زميل طعنا "البيادر" ايد محكم تمييز حكم صادر محكم جنا كبر والقاضي... http://t.co/H0txdjv3Kn
# 1      #الاخبار ▪ تاجيل محا 7 ارهابي سبب غياب دفاع: اجل محكم جنا عاصمه تاريخ لاحق محا سبع ا... http://t.co/GM4jmpAWbR
# 2                                  @helale9999 عشان اعطي وحد صميم صرت ترم اعذار ...حقق عالميهه ارجع كلم ي اياب انتحار
# 3                             #النهد ثما قتل تفجير انتحار سيار مفخخ معمل غاز ريف حمص - شبك صين http://t.co/r5zFEuzAPu
# 4                                          بحرين: ضبط مطلوب متورط تفجير عكر شرق بقي موضوع اضغط http://t.co/t4A5bNrqyh
# ...                                                                                                               ...
# 4995             «بوك حرام »تخطف 40 شاب نيجيري - رياض - رياض «بوك حرام »تخطف 40 شاب نيجيريا... http://t.co/44YL32E037
# 4996                         قصيد مهد شيخ/ ضيف الله سمار كلمات/ سلطان حامد سمار اداء/ عمر شلاح http://t.co/pQ8p6r4n0D
# 4997                                                                                                      عفو مقبره!!
# 4998                                  #للمر اول 92 عاما.. تركي تسمح بناء كنيس جديد - مجل رساءل http://t.co/0bUDDDtD8u
# 4999              جماع "بوك حرام" ارهابيه تختطف شباب ولا "بورنو" نيجيري http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
# [5000 rows x 3 columns]

# %%
def normalize_tweets(text):
   if text is np.nan:
    return ""
   else:
    text = re.sub(r"http\S+", " ", text) # remove urls
    text = re.sub(r"RT ", " ", text) # remove rt
    text = re.sub(r"@[\w]*", " ", text) # remove handles
    text = re.sub(r"[\.\,\#_\|\:\?\?\/\=]", " ", text) # remove special characters
    text = re.sub(r'\t', ' ', text) # remove tabs
    text = re.sub(r'\n', ' ', text) # remove line jump
    text = re.sub(r"\s+", " ", text) # remove extra white space
    accents = re.compile(r'[\u064b-\u0652\u0640]') # harakaat and tatweel (kashida) to remove

    arabic_punc= re.compile(r'[\u0621-\u063A\u0641-\u064A\d+]+') # Keep only Arabic letters/do not remove numbers
    text=' '.join(arabic_punc.findall(accents.sub('',text)))
    text = text.strip()
    return text


def preprocess(sentence):
  sentence =remove_stop_words(sentence)
  sentence =normalize_tweets(sentence)
  sentence =stem(sentence)
  return sentence


data['Clean2_Text']=data['tweetText'].apply(preprocess)
data
# Out:
#                  tweetID  \
# 0     549679192804061184
# 1     549699343666532352
# 2     549711593487888387
# 3     549719610459967488
# 4     549720880717508608
# ...                  ...
# 4995  551574113324920832
# 4996  551574871797272576
# 4997  551574876092256256
# 4998  551575878141222912
# 4999  551576182794506240
#
#                                                                                                                                        tweetText  \
# 0     الاعدام لعامل مطعم قتل زميله طعناً في "البيادر" أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي... http://t.co/H0txdjv3Kn
# 1       #الأخبار ▪ تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع: أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ... http://t.co/GM4jmpAWbR
# 2                                             @helale9999 عشآن أعطيتك وحده صميم صرت ترمي أعذار ...حقق العالميةة و أرجع كلمني يَ الأياب الانتحاري
# 3                             #النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص - شبكة الصين http://t.co/r5zFEuzAPu
# 4                                             البحرين: ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا http://t.co/t4A5bNrqyh
# ...                                                                                                                                          ...
# 4995       «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا - الرياض - الرياض «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا... http://t.co/44YL32E037
# 4996                                  قصيدة مهداة إلى الشيخ/ ضيف الله بن سمار كلمات/ سلطان حامد بن سمار اداء/ عمر الشلآحي http://t.co/pQ8p6r4n0D
# 4997                                                                                                                         العفو عند المقبرة!!
# 4998                                              #للمرة الأولى منذ 92 عاما.. تركيا تسمح ببناء كنيسة جديدة - مجلة الرسائل http://t.co/0bUDDDtD8u
# 4999                   جماعة "بوكو حرام" الإرهابية تختطف الشباب في ولاية "بورنو" شمال شرقي نيجيريا http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
#                                                                                                            Clean_Text  \
# 0     اعدام لعامل مطعم قتل زميل طعنا "البيادر" ايد محكم تمييز حكم صادر محكم جنا كبر والقاضي... http://t.co/H0txdjv3Kn
# 1      #الاخبار ▪ تاجيل محا 7 ارهابي سبب غياب دفاع: اجل محكم جنا عاصمه تاريخ لاحق محا سبع ا... http://t.co/GM4jmpAWbR
# 2                                  @helale9999 عشان اعطي وحد صميم صرت ترم اعذار ...حقق عالميهه ارجع كلم ي اياب انتحار
# 3                             #النهد ثما قتل تفجير انتحار سيار مفخخ معمل غاز ريف حمص - شبك صين http://t.co/r5zFEuzAPu
# 4                                          بحرين: ضبط مطلوب متورط تفجير عكر شرق بقي موضوع اضغط http://t.co/t4A5bNrqyh
# ...                                                                                                               ...
# 4995             «بوك حرام »تخطف 40 شاب نيجيري - رياض - رياض «بوك حرام »تخطف 40 شاب نيجيريا... http://t.co/44YL32E037
# 4996                         قصيد مهد شيخ/ ضيف الله سمار كلمات/ سلطان حامد سمار اداء/ عمر شلاح http://t.co/pQ8p6r4n0D
# 4997                                                                                                      عفو مقبره!!
# 4998                                  #للمر اول 92 عاما.. تركي تسمح بناء كنيس جديد - مجل رساءل http://t.co/0bUDDDtD8u
# 4999              جماع "بوك حرام" ارهابيه تختطف شباب ولا "بورنو" نيجيري http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
#                                                                             Clean2_Text
# 0     اعدام لعامل مطعم قتل زميل طعنا بيادر ايد محكم تمييز حكم صادر محكم جنا كبري والقاض
# 1     اخبار تاجيل محاكم 7 ارهابي سبب غياب دفاع اجل محكم جنا عاصم تاريخ لاحق محاكم سبع ء
# 2                     عشء اعطي وحد صميم صرت ترم اعذار حقق عالمية ارجع كلم ي اياب انتحار
# 3                         نهد ثمان قتلي تفجير انتحار سيار مفخخ معمل غاز ريف حمص شبك صين
# 4                                       بحر ضبط مطلوب متورط تفجير عكر شرق بق موضوع اضغط
# ...                                                                                 ...
# 4995                  وكو حرام تخطف 40 شاب نيجيري رياض رياض وكو حرام تخطف 40 شاب نيجيري
# 4996                     قصيد مهدا شيخ ضيف الله سمار كلما سلطان حامد سمار اداء عمر شلاح
# 4997                                                                           عفو مقبر
# 4998                                للمر اولي 92 عام تركي تسمح بناء كنيس جديد مجل رسايل
# 4999                                      جماع وكو حرام ارهاب تختطف شباب ولا ورن نيجيري
#
# [5000 rows x 4 columns]

# %%
# !pip install qalsadi

import qalsadi.lemmatizer
lemmer = qalsadi.lemmatizer.Lemmatizer()


def arabic_lemmatize(text):
    r = lemmer.lemmatize_text(text)
    lemmatized_text = ' '.join(r)
    return lemmatized_text

# Example Arabic text for lemmatization
text = 'يُشار إلى أن اللغة العربية'

# Lemmatize the Arabic text
lemmatized_text = arabic_lemmatize(text)

print("Original Arabic Text:", text)
print("Lemmatized Arabic Text:", lemmatized_text)
# Out:
# Requirement already satisfied: qalsadi in /usr/local/lib/python3.10/dist-packages (0.5)
# Requirement already satisfied: Arabic-Stopwords>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.4.3)
# Requirement already satisfied: alyahmor>=0.2 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.2)
# Requirement already satisfied: arramooz-pysqlite>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.4.2)
# Requirement already satisfied: codernitydb3 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.6.0)
# Requirement already satisfied: libqutrub>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (1.2.4.1)
# Requirement already satisfied: mysam-tagmanager>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.4)
# Requirement already satisfied: naftawayh>=0.3 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.4)
# Requirement already satisfied: pickledb>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.9.2)
# Requirement already satisfied: pyarabic>=0.6.7 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.6.15)
# Requirement already satisfied: tashaphyne>=0.3.4.1 in /usr/local/lib/python3.10/dist-packages (from qalsadi) (0.3.6)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic>=0.6.7->qalsadi) (1.16.0)
# Original Arabic Text: يُشار إلى أن اللغة العربية
# Lemmatized Arabic Text: شار إلى أن لغة عرب

# %%
def preprocess2(sentence):
  sentence =remove_stop_words(sentence)
  sentence =normalize_tweets(sentence)
  sentence =arabic_lemmatize(sentence)
  return sentence


data['Clean3_Text']=data['tweetText'].apply(preprocess2)
data
# Out:
#                  tweetID  \
# 0     549679192804061184
# 1     549699343666532352
# 2     549711593487888387
# 3     549719610459967488
# 4     549720880717508608
# ...                  ...
# 4995  551574113324920832
# 4996  551574871797272576
# 4997  551574876092256256
# 4998  551575878141222912
# 4999  551576182794506240
#
#                                                                                                                                        tweetText  \
# 0     الاعدام لعامل مطعم قتل زميله طعناً في "البيادر" أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي... http://t.co/H0txdjv3Kn
# 1       #الأخبار ▪ تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع: أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ... http://t.co/GM4jmpAWbR
# 2                                             @helale9999 عشآن أعطيتك وحده صميم صرت ترمي أعذار ...حقق العالميةة و أرجع كلمني يَ الأياب الانتحاري
# 3                             #النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص - شبكة الصين http://t.co/r5zFEuzAPu
# 4                                             البحرين: ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا http://t.co/t4A5bNrqyh
# ...                                                                                                                                          ...
# 4995       «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا - الرياض - الرياض «بوكو حرام »تخطف 40 شابا في شمال شرق نيجيريا... http://t.co/44YL32E037
# 4996                                  قصيدة مهداة إلى الشيخ/ ضيف الله بن سمار كلمات/ سلطان حامد بن سمار اداء/ عمر الشلآحي http://t.co/pQ8p6r4n0D
# 4997                                                                                                                         العفو عند المقبرة!!
# 4998                                              #للمرة الأولى منذ 92 عاما.. تركيا تسمح ببناء كنيسة جديدة - مجلة الرسائل http://t.co/0bUDDDtD8u
# 4999                   جماعة "بوكو حرام" الإرهابية تختطف الشباب في ولاية "بورنو" شمال شرقي نيجيريا http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
#                                                                                                            Clean_Text  \
# 0     اعدام لعامل مطعم قتل زميل طعنا "البيادر" ايد محكم تمييز حكم صادر محكم جنا كبر والقاضي... http://t.co/H0txdjv3Kn
# 1      #الاخبار ▪ تاجيل محا 7 ارهابي سبب غياب دفاع: اجل محكم جنا عاصمه تاريخ لاحق محا سبع ا... http://t.co/GM4jmpAWbR
# 2                                  @helale9999 عشان اعطي وحد صميم صرت ترم اعذار ...حقق عالميهه ارجع كلم ي اياب انتحار
# 3                             #النهد ثما قتل تفجير انتحار سيار مفخخ معمل غاز ريف حمص - شبك صين http://t.co/r5zFEuzAPu
# 4                                          بحرين: ضبط مطلوب متورط تفجير عكر شرق بقي موضوع اضغط http://t.co/t4A5bNrqyh
# ...                                                                                                               ...
# 4995             «بوك حرام »تخطف 40 شاب نيجيري - رياض - رياض «بوك حرام »تخطف 40 شاب نيجيريا... http://t.co/44YL32E037
# 4996                         قصيد مهد شيخ/ ضيف الله سمار كلمات/ سلطان حامد سمار اداء/ عمر شلاح http://t.co/pQ8p6r4n0D
# 4997                                                                                                      عفو مقبره!!
# 4998                                  #للمر اول 92 عاما.. تركي تسمح بناء كنيس جديد - مجل رساءل http://t.co/0bUDDDtD8u
# 4999              جماع "بوك حرام" ارهابيه تختطف شباب ولا "بورنو" نيجيري http://t.co/6unNKQR6nz http://t.co/Pp24IqR80u
#
#                                                                             Clean2_Text  \
# 0     اعدام لعامل مطعم قتل زميل طعنا بيادر ايد محكم تمييز حكم صادر محكم جنا كبري والقاض
# 1     اخبار تاجيل محاكم 7 ارهابي سبب غياب دفاع اجل محكم جنا عاصم تاريخ لاحق محاكم سبع ء
# 2                     عشء اعطي وحد صميم صرت ترم اعذار حقق عالمية ارجع كلم ي اياب انتحار
# 3                         نهد ثمان قتلي تفجير انتحار سيار مفخخ معمل غاز ريف حمص شبك صين
# 4                                       بحر ضبط مطلوب متورط تفجير عكر شرق بق موضوع اضغط
# ...                                                                                 ...
# 4995                  وكو حرام تخطف 40 شاب نيجيري رياض رياض وكو حرام تخطف 40 شاب نيجيري
# 4996                     قصيد مهدا شيخ ضيف الله سمار كلما سلطان حامد سمار اداء عمر شلاح
# 4997                                                                           عفو مقبر
# 4998                                للمر اولي 92 عام تركي تسمح بناء كنيس جديد مجل رسايل
# 4999                                      جماع وكو حرام ارهاب تختطف شباب ولا ورن نيجيري
#
#                                                                               Clean3_Text
# 0       الاعدام عامل مطعم قتل زميل طعن بيادر أيد محكم تمييز حكم صادر محكم جناية كبرى قاضي
# 1     أخبار تأجيل محاكم 7 إرهابي سبب غياب دفاع أجل محكم جناية عاصم تاريخ لاحق محاكم سبع إ
# 2                عشآن أعطية وحد صميم صار أرمى أعذار حقق العالميةة رجع كلم ي الأياب انتحار
# 3                         نهد ثماني قتلى تفجير انتحار سيار مفخخ معمل غاز ريف حمص شبكة لصى
# 4                                          بحر ضبط مطلوب متورط تفجير عكر شرق بق موضوع ضغط
# ...                                                                                   ...
# 4995              بوكو حرام تخطف 40 شاب نيجيري الرياض الرياض بوكو حرام تخطف 40 شاب نيجيري
# 4996                      قصيد مهداة شيخ ضيف الله سمار لمة سلط حامد سمار اداء عمر الشلآحي
# 4997                                                                             عفو مقبر
# 4998                                     مر أولى 92 عام ترك سمح بناء كنيس جديد مجلة رسائل
# 4999                                   جماع بوكو حرام إرهاب اختطف شباب ولاية بورنو نيجيري
#
# [5000 rows x 5 columns]
